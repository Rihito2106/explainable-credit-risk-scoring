# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)

# %%
sns.set_style("whitegrid")

# %%
df = pd.read_csv("german_credit_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
df["Age"].describe()
# Out:
# count    1000.000000
# mean       35.546000
# std        11.375469
# min        19.000000
# 25%        27.000000
# 50%        33.000000
# 75%        42.000000
# max        75.000000
# Name: Age, dtype: float64

# %%
df["Risk"].value_counts()
# Out:
# Risk
# good    700
# bad     300
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
#  10  Risk              1000 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df.describe(include="all").T
# Out:
#                    count unique     top freq      mean          std    min  \
# Unnamed: 0        1000.0    NaN     NaN  NaN     499.5   288.819436    0.0
# Age               1000.0    NaN     NaN  NaN    35.546    11.375469   19.0
# Sex                 1000      2    male  690       NaN          NaN    NaN
# Job               1000.0    NaN     NaN  NaN     1.904     0.653614    0.0
# Housing             1000      3     own  713       NaN          NaN    NaN
# Saving accounts      817      4  little  603       NaN          NaN    NaN
# Checking account     606      3  little  274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN  NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN  NaN    20.903    12.058814    4.0
# Purpose             1000      8     car  337       NaN          NaN    NaN
# Risk                1000      2    good  700       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# ...

# %%
df["Job"].unique()
# Out:
# array([2, 1, 3, 0], dtype=int64)

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna().reset_index(drop=True)

# %%
df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             1   22  female    2     own          little         moderate
# 1             3   45    male    2    free          little           little
# 2             4   53    male    2    free          little           little
# 3             7   35    male    3    rent          little         moderate
# 4             9   28    male    3     own          little         moderate
# ..          ...  ...     ...  ...     ...             ...              ...
# 517         989   48    male    1     own          little         moderate
# 518         993   30    male    3     own          little           little
# 519         996   40    male    3     own          little           little
# 520         998   23    male    2    free          little           little
# 521         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'Job', 'Housing', 'Saving accounts',
#        'Checking account', 'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
df[["Age","Credit amount","Duration"]].hist(bins = 7, edgecolor = "black")
plt.suptitle("Distribution of numerical features", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 5))
for i, col in enumerate(["Age", "Credit amount", "Duration"]):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(y = df[col], color = "skyblue")
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
df.query("Duration>=60")
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 18    63    male    2     own          little           little           6836
# 176   24  female    3     own        moderate         moderate           7408
# 199   60  female    3    free        moderate         moderate          14782
# 358   24    male    2     own        moderate         moderate           5595
# 378   27    male    3     own          little         moderate          14027
# 489   42    male    2    free          little         moderate           6288
# 507   36    male    2    rent          little           little           7297
#
#      Duration          Purpose Risk
# 18         60         business  bad
# 176        60              car  bad
# 199        60  vacation/others  bad
# 358        72         radio/TV  bad
# 378        60              car  bad
# 489        60        education  bad
# 507        60         business  bad

# %%
categorical_cols = ["Sex", "Job", "Housing", "Saving accounts","Checking account", "Purpose"]

# %%
plt.figure(figsize=(10, 10))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data=df, x=col, hue=col, palette="Set2", order=df[col].value_counts().index, legend=False)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
corr = df[["Age","Job","Credit amount","Duration"]].corr()

# %%
corr
# Out:
#                     Age       Job  Credit amount  Duration
# Age            1.000000  0.039771       0.082014  0.001549
# Job            0.039771  1.000000       0.334721  0.200794
# Credit amount  0.082014  0.334721       1.000000  0.613298
# Duration       0.001549  0.200794       0.613298  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
df.groupby("Job")["Credit amount"].mean()
# Out:
# Job
# 0    1767.857143
# 1    2250.715517
# 2    3129.130990
# 3    5648.784810
# Name: Credit amount, dtype: float64

# %%
df.groupby("Sex")["Credit amount"].mean()
# Out:
# Sex
# female    2937.202381
# male      3440.833333
# Name: Credit amount, dtype: float64

# %%
pd.pivot_table(df, values="Credit amount", index="Housing", columns="Purpose")
# Out:
# Purpose     business          car  domestic appliances    education  \
# Housing
# free     4705.000000  5180.314286                  NaN  5314.250000
# own      3725.973684  3120.485437               1333.5  2625.076923
# rent     6180.833333  3398.285714                  NaN  2627.857143
#
# Purpose  furniture/equipment     radio/TV  repairs  vacation/others
# Housing
# free             4419.444444  2097.000000   1190.0      7842.666667
# own              3031.100000  2307.613861   2993.5     10321.833333
# rent             2890.285714  2138.000000   2384.0              NaN

# %%
sns.scatterplot(data = df, x= "Age", y="Credit amount", hue = "Sex", size = "Duration", alpha=0.7, palette = "Set1")
plt.title("Credit amount vs Age colored by Sex and sized by Duration")
plt.show()

# %%
sns.violinplot(data = df, x= "Saving accounts", y = "Credit amount", hue = "Saving accounts", palette = "Pastel1", legend=False)
plt.title("Credit Amount Distribution by Saving Accounts")
plt.show()

# %%
df["Risk"].value_counts(normalize=True) * 100
# Out:
# Risk
# good    55.747126
# bad     44.252874
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 4))
for i, col in enumerate(["Age", "Credit amount", "Duration"]):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(data = df, x = "Risk", y = col, hue = "Risk", palette = "Pastel2", legend = False)
    plt.title(f"{col} by Risk")

plt.tight_layout()
plt.show()

# %%
df.groupby("Risk")[["Age", "Credit amount", "Duration"]].mean()
# Out:
#             Age  Credit amount   Duration
# Risk
# bad   34.147186    3881.090909  25.445887
# good  35.477663    2800.594502  18.079038

# %%
plt.figure(figsize=(10, 10))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data = df, x = col, hue = "Risk", palette = "Set1", order = df[col].value_counts().index)
    plt.title(f"{col} by Risk")
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
features = ["Age", "Sex", "Job", "Housing", "Saving accounts", "Checking account", "Credit amount","Duration"]

# %%
target="Risk"

# %%
df_model = df[features + [target]].copy()
df_model.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   22  female    2     own          little         moderate           5951
# 1   45    male    2    free          little           little           7882
# 2   53    male    2    free          little           little           4870
# 3   35    male    3    rent          little         moderate           6948
# 4   28    male    3     own          little         moderate           5234
#
#    Duration  Risk
# 0        48   bad
# 1        42  good
# 2        24   bad
# 3        36  good
# 4        30   bad

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
cat_cols = df_model.select_dtypes(include = "object").columns.drop("Risk")

# %%
le_dict = {}

# %%
cat_cols
# Out:
# Index(['Sex', 'Housing', 'Saving accounts', 'Checking account'], dtype='object')

# %%
for col in cat_cols:
    le = LabelEncoder()
    df_model[col] = le.fit_transform(df_model[col])
    le_dict[col] = le
    joblib.dump(le, f"{col}_encoder.pkl")

# %%
le_target = LabelEncoder()

# %%
target
# Out:
# 'Risk'

# %%
df_model[target] = le_target.fit_transform(df_model[target])

# %%
df_model[target].value_counts()
# Out:
# Risk
# 1    291
# 0    231
# Name: count, dtype: int64

# %%
joblib.dump(le_target, "target_encoder.pkl")
# Out:
# ['target_encoder.pkl']

# %%
df_model.head()
# Out:
#    Age  Sex  Job  Housing  Saving accounts  Checking account  Credit amount  \
# 0   22    0    2        1                0                 1           5951
# 1   45    1    2        0                0                 0           7882
# 2   53    1    2        0                0                 0           4870
# 3   35    1    3        2                0                 1           6948
# 4   28    1    3        1                0                 1           5234
#
#    Duration  Risk
# 0        48     0
# 1        42     1
# 2        24     0
# 3        36     1
# 4        30     0

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_model.drop(target, axis = 1)

# %%
y = df_model[target]

# %%
X
# Out:
#      Age  Sex  Job  Housing  Saving accounts  Checking account  Credit amount  \
# 0     22    0    2        1                0                 1           5951
# 1     45    1    2        0                0                 0           7882
# 2     53    1    2        0                0                 0           4870
# 3     35    1    3        2                0                 1           6948
# 4     28    1    3        1                0                 1           5234
# ..   ...  ...  ...      ...              ...               ...            ...
# 517   48    1    1        1                0                 1           1743
# 518   30    1    3        1                0                 0           3959
# 519   40    1    3        1                0                 0           3857
# 520   23    1    2        0                0                 0           1845
# 521   27    1    2        1                1                 1           4576
#
#      Duration
# 0          48
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 517    1
# 518    1
# 519    1
# 520    0
# 521    1
# Name: Risk, Length: 522, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 1)

# %%
X_train.shape
# Out:
# (417, 8)

# %%
X_test.shape
# Out:
# (105, 8)

# %%
from sklearn.metrics import average_precision_score, roc_auc_score
# !pip install xgboost
import xgboost as xgb

# %%
# Second cut: From the training set, make a validation set (60% train, 20% validation, 20% test)
X_tr, X_va, y_tr, y_va = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=1)

# %%
# Calculate class imbalance weight (Good vs Bad risk)
neg = int((y_tr == 0).sum())
pos = int((y_tr == 1).sum())
spw = neg / max(pos, 1)

# %%
print("Train / Val / Test shapes:", X_tr.shape, X_va.shape, X_test.shape)
print(f"neg: {neg}, pos:{pos}, scale_positive_weight (spw):{round(spw, 1)}")
# Out:
# Train / Val / Test shapes: (312, 8) (105, 8) (105, 8)
# neg: 138, pos:174, scale_positive_weight (spw):0.8

# %%
# Convert to DMatrix (XGBoost's native data structure)
feat_names = list(X_tr.columns)
dtr = xgb.DMatrix(X_tr, label=y_tr, feature_names=feat_names)
dva = xgb.DMatrix(X_va, label=y_va, feature_names=feat_names)
dte = xgb.DMatrix(X_test, label=y_test, feature_names=feat_names)

# %%
params = dict(
    objective="binary:logistic",  
    eval_metric="aucpr",          
    tree_method="hist",           
    max_depth=5,
    eta=0.03,                     
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    scale_pos_weight=spw
)

# Train baseline with early stopping
bst = xgb.train(
    params=params,
    dtrain=dtr,
    num_boost_round=100,         # Force it to build exactly 100 trees
    evals=[(dte, "test")],       # Just watch the test set directly
    verbose_eval=False
)

# %%
cons = [0] * len(feat_names)
if "Credit amount" in feat_names: cons[feat_names.index("Credit amount")] = -1
if "Duration" in feat_names: cons[feat_names.index("Duration")] = -1
if "Age" in feat_names: cons[feat_names.index("Age")] = 1
if "Saving accounts" in feat_names: cons[feat_names.index("Saving accounts")] = 1
if "Checking account" in feat_names: cons[feat_names.index("Checking account")] = 1

mono_string = "(" + ",".join(map(str, cons)) + ")"

params_cons = params.copy()
params_cons.update({"monotone_constraints": mono_string})

bst_cons = xgb.train(
    params=params_cons,
    dtrain=dtr,
    num_boost_round=100,
    evals=[(dte, "test")],
    verbose_eval=False
)

# %%
p_base = bst.predict(dte)
p_cons = bst_cons.predict(dte)

print("--- MODEL COMPARISON ---")
print("PR AUC  baseline     :", round(average_precision_score(y_test, p_base), 3))
print("PR AUC  constrained  :", round(average_precision_score(y_test, p_cons), 3))
print("ROC AUC baseline     :", round(roc_auc_score(y_test, p_base), 3))
print("ROC AUC constrained  :", round(roc_auc_score(y_test, p_cons), 3))
# Out:
# --- MODEL COMPARISON ---
# PR AUC  baseline     : 0.739
# PR AUC  constrained  : 0.73
# ROC AUC baseline     : 0.703
# ROC AUC constrained  : 0.713

# %%
import numpy as np
import shap

print(f"NumPy version: {np.__version__}")
print(f"SHAP version: {shap.__version__}")
print("Everything imported successfully!")
# Out:
# NumPy version: 1.26.4
# SHAP version: 0.45.1
# Everything imported successfully!

# %%
# 1. Use TreeExplainer (Built specifically for XGBoost native boosters)
explainer = shap.TreeExplainer(bst_cons)

# 2. Calculate the SHAP values (This will return a modern SHAP Explanation object)
shap_values = explainer(X_test)

# %%
# Generate the Summary/Beeswarm plot
plt.figure(figsize=(10, 6))
shap.plots.beeswarm(shap_values, max_display=10)

# %%
# Generate a Waterfall plot for a single applicant
shap.plots.waterfall(shap_values[0])

# %%
bst_cons.save_model("models/xgb_constrained_model.json")
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 bst_cons.save_model("models/xgb_constrained_model.json")
#
# File ~\anaconda3\envs\credit_env\lib\site-packages\xgboost\core.py:2534, in Booster.save_model(self, fname)
#    2532 if isinstance(fname, (str, os.PathLike)):  # assume file name
#    2533     fname = os.fspath(os.path.expanduser(fname))
# -> 2534     _check_call(_LIB.XGBoosterSaveModel(self.handle, c_str(fname)))
#    2535 else:
#    2536     raise TypeError("fname must be a string or os PathLike")
#
# File ~\anaconda3\envs\credit_env\lib\site-packages\xgboost\core.py:282, in _check_call(ret)
#     271 """Check the return value of C API call
#     272
#     273 This function will raise exception when error occurs.
#    (...)
#     279     return value from API calls
#     280 """
#     281 if ret != 0:
# ...
